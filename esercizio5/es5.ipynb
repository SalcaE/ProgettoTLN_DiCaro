# %% [markdown]
# # Esercizio Lab-5 : Topic Modeling

# %% [markdown]
# ## Librerie principali

# %%
import gensim
from pprint import pprint
from gensim import corpora
import nltk
nltk.download('stopwords', quiet=True)
import os
from nltk.corpus import stopwords
import string
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# %% [markdown]
# ## Elaborazione testi

# %% [markdown]
# E' stato usato un corpus di 1000 documenti riguardanti recensioni di film estratti da nltk. Nella funzione "text_processing" i documenti vengono elaborati rimuovendo le stopwords e tenendo solo in considerazione i sostantivi (POS=noun)

# %%
def text_processing(file_location):
    texts=[]
    stop = set(stopwords.words('english') + list(string.punctuation) + ['--','-','``',"\""])
    for file_name in os.listdir(file_location):
        with open(file_location + file_name, 'r') as f:
            text = f.read().replace("\n",' ')
            tmp = nltk.word_tokenize(text)
            tokens = [doc[0].lower() for doc in nltk.pos_tag(tmp) if doc[0] not in stop and doc[1] in ['NN','NNS','NNP','NNPS']]
            texts.append(tokens)
    return texts

# %% [markdown]
# ## Modello LDA

# %% [markdown]
# E' stata utilizzata la libreria gensim per la creazione del modello LDA salvando il risultato all'interno di un file html. Nell'esempio fornito il modello è stato testato con 20 topic.

# %%
def lda_process(texts,num_topic):
    dictionary = corpora.Dictionary(texts)
    corpus = [dictionary.doc2bow(text) for text in texts]

    lda_model = gensim.models.LdaMulticore(corpus=corpus, id2word=dictionary, num_topics=num_topic)
  
    lda = gensimvis.prepare(lda_model, corpus, dictionary)

    pyLDAvis.save_html(lda,'esercizio5/htmlResults.html')
  
    print(num_topic,' TOPIC')
    pprint(lda_model.print_topics())
# Out:
# 20  TOPIC
# [(0,
#   '0.040*"film" + 0.014*"movie" + 0.008*"time" + 0.006*"films" + 0.005*"story" '
#   '+ 0.004*"characters" + 0.004*"people" + 0.004*"scenes" + 0.004*"life" + '
#   '0.004*"plot"'),
#  (1,
#   '0.017*"film" + 0.008*"movie" + 0.006*"time" + 0.005*"character" + '
#   '0.005*"scene" + 0.005*"man" + 0.004*"story" + 0.004*"scenes" + '
#   '0.004*"characters" + 0.004*"life"'),
#  (2,
#   '0.024*"film" + 0.009*"movie" + 0.007*"time" + 0.006*"character" + '
#   '0.006*"story" + 0.004*"films" + 0.004*"director" + 0.004*"way" + '
#   '0.004*"scenes" + 0.003*"characters"'),
#  (3,
#   '0.024*"film" + 0.008*"time" + 0.007*"movie" + 0.004*"scenes" + '
#   '0.004*"character" + 0.004*"films" + 0.004*"world" + 0.004*"way" + '
#   '0.004*"scene" + 0.003*"action"'),
#  (4,
#   '0.022*"film" + 0.010*"movie" + 0.007*"time" + 0.005*"things" + 0.004*"life" '
#   '+ 0.004*"plot" + 0.004*"films" + 0.004*"scene" + 0.004*"way" + '
#   '0.004*"action"'),
#  (5,
# ...

# %%
from IPython.display import HTML
HTML(filename='esercizio5/htmlResults.html')
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el3254819412453999368341000673" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...
